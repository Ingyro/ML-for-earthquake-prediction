# %% [markdown]
# # Procesamiento del Vector de entrenamiento

# %%
#Importo las librerias pandas, numpy y datetime
import pandas as pd
import numpy as np
import datetime

# %%
#Cargo el catálogo declusterizado
df = pd.read_csv("salida.csv", sep=',', decimal='.')

# %%
#Ordeno el catálogo por cronología siendo el primer evento el más antigüo y el último el más reciente del catálogo
df['date'] = pd.to_datetime(df[['year', 'month', 'day', 'hour', 'minute']])
df =df.sort_values(by='date',ascending=True)
print(df)
# Out:
#       eventID  Agency  year  month  day  hour  minute  second  timeError  \
# 1728     1747     NaN  2004     11   19     0      20     0.0        NaN
# 1729     1748     NaN  2005      1    2     5      24     0.0        NaN
# 1730     1749     NaN  2005      1    8     4       9     0.0        NaN
# 1731     1750     NaN  2005      4   24     3       9     0.0        NaN
# 1732     1751     NaN  2005     12   23     4      53     0.0        NaN
# ...       ...     ...   ...    ...  ...   ...     ...     ...        ...
# 1724     1743     NaN  2018      2   19    10      11     0.0        NaN
# 1725     1744     NaN  2018      2   25     9      37     0.0        NaN
# 1726     1745     NaN  2019      5   10     3      52     0.0        NaN
# 1712     1731     NaN  2019      5   11     9      56     0.0        NaN
# 1727     1746     NaN  2019     11   27     6      56     0.0        NaN
#
#       longitude  latitude  SemiMajor90  SemiMinor90  ErrorStrike  depth  \
# 1728  -730940.0   68450.0          NaN          NaN          NaN  175.0
# 1729  -732050.0   68110.0          NaN          NaN          NaN  167.0
# 1730  -732210.0   68900.0          NaN          NaN          NaN  168.0
# 1731  -731660.0   67390.0          NaN          NaN          NaN  160.0
# 1732  -731230.0   67720.0          NaN          NaN          NaN  164.0
# ...         ...       ...          ...          ...          ...    ...
# 1724  -731590.0   68380.0          NaN          NaN          NaN  146.0
# 1725  -731520.0   68420.0          NaN          NaN          NaN  144.0
# 1726  -731200.0   68200.0          NaN          NaN          NaN  145.0
# 1712  -731400.0   69200.0          NaN          NaN          NaN  149.0
# 1727  -731800.0   68200.0          NaN          NaN          NaN  146.0
#
#       depthError  magnitude  sigmaMagnitude  magnitudeType                date
# 1728         NaN        2.6             2.6            NaN 2004-11-19 00:20:00
# 1729         NaN        1.8             1.8            NaN 2005-01-02 05:24:00
# 1730         NaN        1.7             1.7            NaN 2005-01-08 04:09:00
# 1731         NaN        2.4             2.4            NaN 2005-04-24 03:09:00
# 1732         NaN        1.9             1.9            NaN 2005-12-23 04:53:00
# ...          ...        ...             ...            ...                 ...
# 1724         NaN        3.4             3.4            NaN 2018-02-19 10:11:00
# 1725         NaN        3.6             3.6            NaN 2018-02-25 09:37:00
# 1726         NaN        7.1             7.1            NaN 2019-05-10 03:52:00
# 1712         NaN        3.5             3.5            NaN 2019-05-11 09:56:00
# 1727         NaN        4.8             4.8            NaN 2019-11-27 06:56:00
#
# [1736 rows x 20 columns]

# %% [markdown]
# # Hallamos el b-value de todo el catálogo

# %%
#Cálculamos el b-value para todo el catálogo
magnitud = df.iloc[:,16].tolist()
b_value=[]
for idx, val in enumerate(magnitud,start=0):
    sumatoria=0
    for j in range(0,49):      
650988486666667, 0.9737544437219733, 0.9915399130136988, 0.9960882612385323, 0.9960882612385322, 1.0053113006944445, 1.0242794384433962, 1.0291338433649286, 1.0857362047499997, 1.0644472595588235, 1.080334532089552, 1.1078940864795916, 1.1368965494764396, 1.119315675, 1.1135755946153845, 1.1022702586294417, 1.148927200793651, 1.1368965494764398, 1.1368965494764398, 1.1865969450819673, 1.1737688700000002, 1.1674582846774197, 1.1737688700000002, 1.1865969450819673, 1.2199283199438204, 1.2199283199438204, 1.226820570338983, 1.1997085135359113, 1.206373560833333, 1.206373560833333, 1.2479726491379308, 1.2408413768571425, 1.2408413768571425, 1.2408413768571425, 1.2624839590116275, 1.247972649137931, 1.262483959011628, 1.277336711470588, 1.277336711470588, 1.2773367114705885, 1.262483959011628, 1.269866906140351, 1.2698669061403511, 1.2698669061403511, 1.2698669061403511, 1.2848949168639057, 1.269866906140351, 1.2698669061403507, 1.269866906140351, 1.2408413768571427, 1.2408413768571427, 1.226820570338983, 1.1737688699999997, 1.1737688699999997, 1.1737688699999997, 1.1550385156914889, 1.1550385156914889,  ...
# 1736

# %% [markdown]
# # Hallamos los primeros 5 valores del vector de entrenamiento

# %%
#Calculamos las primeras 5 características del Vector de entrenamiento.
Tv={}
for i in range(0,len(b_value)):
    x1=b_value[i]-b_value[i-4]
    x2=b_value[i-4]-b_value[i-8]
    x3=b_value[i-8]-b_value[i-12]
    x4=b_value[i-12]-b_value[i-16]
    x5=b_value[i-16]-b_value[i-20]
    Tv[i]={x1,x2,x3,x4,x5}
print(len(Tv))
print(Tv)
# Out:
# 1736
# {0: {-0.015636701133980746, 0.00039281907290633633, 0.0011413224105518704, 0.001948361623293482, 0.00192252128346182}, 1: {0.004349904666466398, 0.0023411806961997073, 0.0011443498015871745, -0.013863491588414878, 0.0015400595460613453}, 2: {0.009650064719787521, -0.0011690085827980035, 0.0023286775497546874, -0.011194233858412395, 0.001150440831940991}, 3: {0.019663488351632064, 0.0007824787430813496, 0.0023224635034010954, -0.01768876188905172, 0.00038347892287232677}, 4: {0.02084128479582925, -0.015636701133980746, 0.00039281907290633633, 0.001948361623293482, 0.00192252128346182}, 5: {0.02095863157479244, 0.0023411806961997073, 0.004349904666466398, -0.013863491588414878, 0.0015400595460613453}, 6: {0.022339570145895604, -0.0011690085827980035, 0.0023286775497546874, 0.009650064719787521, -0.011194233858412395}, 7: {0.02316397382791896, 0.0007824787430813496, -0.01768876188905172, 0.0023224635034010954, 0.019663488351632064}, 8: {0.02423764231811265, 0.02084128479582925, -0.015636701133980746, 0.001948361623293482, 0.00039281907290633633}, 9: {0.02332654243923238, 0.0023411806961997073, 0.004349904666466398, 0.02095863157479244, -0.013863491588414878}, 10: {0.021948716498716714, 0.022339570145895604, 0.009650064719787521, -0.0011690085827980035, -0.011194233858412395}, 11: {0.02335290557776354, 0.019663488351632064, -0.01768876188905172, 0.02316397382791896, 0.0007824787430813496}, 12: {0.027973879671497615, 0.02423764231811265, -0.015636701133980746, 0.00039281907290633633, 0.
# 1732  0.000393  0.001948  0.001141  0.001132  0.001923
# 1733 -0.013863  0.002341  0.001144  0.001887  0.001540
# 1734 -0.011194 -0.001169  0.002329  0.001150  0.002274
# 1735 -0.017689  0.000782  0.002280  0.002322  0.000383
#
# [1736 rows x 5 columns]

# %% [markdown]
# # Hallamos x6

# %%
#Extraemos la fecha y la magnitud para poder calcular mas fácil la característica x6 del Vector de entrenamiento
data = pd.DataFrame()
data['date'] = df['date']
data['magnitud']=df['magnitude']

# %%
#Visualizamos el dataframe generado
df=data.set_index(['date'])
df
# Out:
#                      magnitud
# date
# 2004-11-19 00:20:00       2.6
# 2005-01-02 05:24:00       1.8
# 2005-01-08 04:09:00       1.7
# 2005-04-24 03:09:00       2.4
# 2005-12-23 04:53:00       1.9
# ...                       ...
# 2018-02-19 10:11:00       3.4
# 2018-02-25 09:37:00       3.6
# 2019-05-10 03:52:00       7.1
# 2019-05-11 09:56:00       3.5
# 2019-11-27 06:56:00       4.8
#
# [1736 rows x 1 columns]

# %%
#Calculamos el x6
w=pd.DataFrame()
j=[]
inicial=df.index[548]
final=df.index[548]-datetime.timedelta(days=7)
df[final:inicial]
for i in range(len(data)):
    inicial=df.index[i]
    final=df.index[i]-datetime.timedelta(days=7)
    w=df[final:inicial].max()
    j.append(w)
x6 = np.array(j)
print(len(x6))
print(x6)
# Out:
# 1736
# [[2.6]
#  [1.8]
#  [1.8]
#  ...
#  [7.1]
#  [7.1]
#  [4.8]]

# %%
#Agregamos la lista anterior al vector de entrenamiento
Training['x6']=x6
Training
# Out:
#             x1        x2        x3        x4        x5   x6
# 0    -0.015637  0.000393  0.001141  0.001948  0.001923  2.6
# 1     0.004350  0.002341  0.001144 -0.013863  0.001540  1.8
# 2     0.009650 -0.001169  0.002329 -0.011194  0.001150  1.8
# 3     0.019663  0.000782  0.002322 -0.017689  0.000383  2.4
# 4     0.020841 -0.015637  0.000393  0.001948  0.001923  1.9
# ...        ...       ...       ...       ...       ...  ...
# 1731  0.000782  0.002280  0.000376  0.002322  0.000383  4.2
# 1732  0.000393  0.001948  0.001141  0.001132  0.001923  3.6
# 1733 -0.013863  0.002341  0.001144  0.001887  0.001540  7.1
# 1734 -0.011194 -0.001169  0.002329  0.001150  0.002274  7.1
# 1735 -0.017689  0.000782  0.002280  0.002322  0.000383  4.8
#
# [1736 rows x 6 columns]

# %% [markdown]
# # Hallamos el X7

# %%
#Calculamos el x7
w=pd.DataFrame()
j=[]
inicial=df.index[548]
final=df.index[548]+datetime.timedelta(days=7)
df[final:inicial]
for i in range(len(data)):
    inicial=df.index[i]
    final=df.index[i]+datetime.timedelta(days=7)
    w=df[inicial:final].max()
    j.append(w)
x7 = np.array(j)
print(len(x7))
print(x7)
# Out:
# 1736
# [[2.6]
#  [1.8]
#  [1.7]
#  ...
#  [7.1]
#  [3.5]
#  [4.8]]

# %%
#Agregamos la lista anterior al vector de entrenamiento
Training['x7']=x7
Training
# Out:
#             x1        x2        x3        x4        x5   x6   x7
# 0    -0.015637  0.000393  0.001141  0.001948  0.001923  2.6  2.6
# 1     0.004350  0.002341  0.001144 -0.013863  0.001540  1.8  1.8
# 2     0.009650 -0.001169  0.002329 -0.011194  0.001150  1.8  1.7
# 3     0.019663  0.000782  0.002322 -0.017689  0.000383  2.4  2.4
# 4     0.020841 -0.015637  0.000393  0.001948  0.001923  1.9  1.9
# ...        ...       ...       ...       ...       ...  ...  ...
# 1731  0.000782  0.002280  0.000376  0.002322  0.000383  4.2  3.6
# 1732  0.000393  0.001948  0.001141  0.001132  0.001923  3.6  3.6
# 1733 -0.013863  0.002341  0.001144  0.001887  0.001540  7.1  7.1
# 1734 -0.011194 -0.001169  0.002329  0.001150  0.002274  7.1  3.5
# 1735 -0.017689  0.000782  0.002280  0.002322  0.000383  4.8  4.8
#
# [1736 rows x 7 columns]

# %% [markdown]
# # Hallamos el Y

# %%
#Calculamos el y
w=pd.DataFrame()
j=[]
inicial=df.index[548]
final=df.index[548]+datetime.timedelta(days=7)
df[final:inicial]
for i in range(len(data)):
    inicial=df.index[i]
    final=df.index[i]+datetime.timedelta(days=7)
    w=df[inicial:final].max()
    j.append(w)
print(len(j))
y=np.array(j)
y
# Out:
# 1736
# array([[2.6],
#        [1.8],
#        [1.7],
#        ...,
#        [7.1],
#        [3.5],
#        [4.8]])

# %%
#Agregamos la lista anterior al vector de entrenamiento
Training['y']=y
Training
# Out:
# x1    float64
# x2    float64
# x3    float64
# x4    float64
# x5    float64
# x6    float64
# x7    float64
# y     float64
# dtype: object

# %%
#Revisamos si tenemos valores vacíos o NaN
print(Training.isnull().any())
print(Training.isnull().sum().sum())
# Out:
# x1    False
# x2    False
# x3    False
# x4    False
# x5     True
# x6    False
# x7    False
# y     False
# dtype: bool
# 6

# %%
#Rellenamos los valores vacíos con 0
Training = Training.fillna(0)

# %%
#Creamos un archivo llamado Tv.csv donde se guarda el Vector de entrenamiento final.
Training = np.around(Training,decimals=6)
Training.to_csv(r'c:\Users\yesid\Documents\Tv.csv', index = False)
Training.shape
Training
# Out:
#             x1        x2        x3        x4        x5   x6   x7    y
# 0    -0.015637  0.000393  0.001141  0.001948  0.001923  2.6  2.6  2.6
# 1     0.004350  0.002341  0.001144 -0.013863  0.001540  1.8  1.8  1.8
# 2     0.009650 -0.001169  0.002329 -0.011194  0.001150  1.8  1.7  1.7
# 3     0.019663  0.000782  0.002322 -0.017689  0.000383  2.4  2.4  2.4
# 4     0.020841 -0.015637  0.000393  0.001948  0.001923  1.9  1.9  1.9
# ...        ...       ...       ...       ...       ...  ...  ...  ...
# 1731  0.000782  0.002280  0.000376  0.002322  0.000383  4.2  3.6  3.6
# 1732  0.000393  0.001948  0.001141  0.001132  0.001923  3.6  3.6  3.6
# 1733 -0.013863  0.002341  0.001144  0.001887  0.001540  7.1  7.1  7.1
# 1734 -0.011194 -0.001169  0.002329  0.001150  0.002274  7.1  3.5  3.5
# 1735 -0.017689  0.000782  0.002280  0.002322  0.000383  4.8  4.8  4.8
#
# [1736 rows x 8 columns]
